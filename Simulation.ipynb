# %%
import pandas as pd
from mmcqueues import MMCQueue, ARRIVAL_RATES, SERVICE_RATES


max_Wq = 0.5
output = {}
for l in ARRIVAL_RATES:
    output[l] = {}
    for mu in SERVICE_RATES:
        for c in range(1, 350):
            if c * mu - l < 0:
                continue
            else:
                q = MMCQueue(l, mu, c)
                if q.Wq < 0.5:
                    output[l][mu] = {'c': c, 'Wq': q.Wq}
                    break

pd.DataFrame(output).transpose()
# Out:
#                                                   1.9  \
# 9      {'c': 6, 'Wq': 0.2069504733704905498517880014}
# 11     {'c': 7, 'Wq': 0.2367613377942975385938072149}
# 13     {'c': 8, 'Wq': 0.2661310257093148457136697485}
# 15     {'c': 9, 'Wq': 0.2958694247903186584449538437}
# 19    {'c': 10, 'Wq': -1125899906842782.943492511881}
# 22    {'c': 13, 'Wq': 0.2211571244088265286148842626}
# 25    {'c': 14, 'Wq': 0.4721271057348978324007675568}
# 26    {'c': 15, 'Wq': 0.2580952658657101156054375201}
# 31    {'c': 18, 'Wq': 0.1855038664267767758635045043}
# 37    {'c': 21, 'Wq': 0.2241735532236892243878768489}
# 43    {'c': 24, 'Wq': 0.2692406392727003838990951863}
# 45    {'c': 25, 'Wq': 0.2861991461953316019400793678}
# 57    {'c': 30, 'Wq': -375299968947594.3651860153818}
# 68     {'c': 37, 'Wq': 0.338416764236090160854354885}
# 79    {'c': 43, 'Wq': 0.2814441282983900465769123082}
# 81    {'c': 44, 'Wq': 0.2963171018227527209355063989}
# 101   {'c': 55, 'Wq': 0.2078941588401199892956724025}
# 121   {'c': 65, 'Wq': 0.3257608138035955834154361245}
# 141   {'c': 76, 'Wq': 0.2265333472482489778500491514}
# 145   {'c': 78, 'Wq': 0.2453681159796280703987184697}
# 181   {'c': 97, 'Wq': 0.2423537455228335754008251256}
# 217  {'c': 116, 'Wq': 0.2383112433382483115713037506}
# 253  {'c': 135, 'Wq': 0.2337552860268970711728962571}
# 260  {'c': 138, 'Wq': 0.4018292350538429376139018308}
# 325  {'c': 173, 'Wq': 0.2240818160528855589882439441}
# 370  {'c': 196, 'Wq': 0.3721488281265792878651146743}
# 390  {'c': 207, 'Wq': 0.2602547461893581392472547167}
# 455  {'c': 241, 'Wq': 0.3047598589870124591063208721}
# 463  {'c': 245, 'Wq': 0.3600125574670867420267148652}
# 555  {'c': 294, 'Wq': 0.2416456452203919468897110357}
# 648  {'c': 343, 'Wq': 0.2367107889902019116454500991}
#
#                                                   6.3
# 9      {'c': 2, 'Wq': 0.1653439153439153676141501156}
# 11     {'c': 3, 'Wq': 0.0420263033633881133331293744}
# 13      {'c': 3, 'Wq': 0.080445880943508849261594382}
# 15     {'c': 3, 'Wq': 0.1633053205918603195825656072}
# 19    {'c': 4, 'Wq': 0.08324448079053531084580721742}
# 22     {'c': 4, 'Wq': 0.2293620534966717411325631963}
# 25    {'c': 5, 'Wq': 0.08337479986224074341458160412}
# 26     {'c': 5, 'Wq': 0.1098375309008591824701736672}
# 31    {'c': 6, 'Wq': 0.08225087901585870052794545003}
# 37    {'c': 7, 'Wq': 0.08049623529873107681460635695}
# 43    {'c': 8, 'Wq': 0.07842472022199904256420616170}
# 45     {'c': 8, 'Wq': 0.1263449230378498461662275573}
# 57    {'c': 10, 'Wq': 0.1138167352438901412213519500}
# 68   {'c': 12, 'Wq': 0.08399653272760296849024752104}
# 79    {'c': 13, 'Wq': 0.2954585527664398930916938004}
# 81   {'c': 14, 'Wq': 0.09407321505772274326126249075}
# 101   {'c': 17, 'Wq': 0.1221014755604801631107207887}
# 121   {'c': 20, 'Wq': 0.1605171463380479003255634967}
# 141   {'c': 23, 'Wq': 0.2188451503915984323138315130}
# 145   {'c': 24, 'Wq': 0.1254479483027925088402639212}
# 181  {'c': 30, 'Wq': 0.09321796884473654502561041646}
# 217   {'c': 35, 'Wq': 0.2546271985481758482157367384}
# 253   {'c': 41, 'Wq': 0.1602943541614472330916155085}
# 260   {'c': 42, 'Wq': 0.1891324040097697284688023588}
# 325   {'c': 52, 'Wq': 0.3585824805736940626209120858}
# 370   {'c': 60, 'Wq': 0.1017234800434620831774798392}
# 390   {'c': 63, 'Wq': 0.1219601893583638954954596846}
# 455   {'c': 73, 'Wq': 0.1822998170983782876464864052}
# 463   {'c': 74, 'Wq': 0.2905828522777761366655918037}
# 555   {'c': 89, 'Wq': 0.1557052725569569795876169928}
# 648  {'c': 104, 'Wq': 0.1207255678655525198381833194}
